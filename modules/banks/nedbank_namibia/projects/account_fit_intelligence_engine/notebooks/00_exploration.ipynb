# %% [markdown]
# # Data Exploration - Account Fit Intelligence Engine
#
# This notebook explores the synthetic customer and transaction data to understand patterns and validate data quality.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set plotting style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# ## Load Data

# %%
# Load customer data
customers = pd.read_csv('../data/synthetic/customers_sample.csv')
print(f"Loaded {len(customers)} customers")
customers.head()

# %%
# Load transaction data
transactions = pd.read_csv('../data/synthetic/transactions_sample.csv')
transactions['ts'] = pd.to_datetime(transactions['ts'])
print(f"Loaded {len(transactions)} transactions")
transactions.head()

# %% [markdown]
# ## Customer Analysis

# %%
# TODO: Add customer analysis
# - Age distribution
# - Income distribution
# - Summary statistics

# %% [markdown]
# ## Transaction Analysis

# %%
# TODO: Add transaction analysis
# - Transaction type distribution
# - Amount distribution
# - Temporal patterns
# - Transactions per customer

# %% [markdown]
# ## Data Quality Checks

# %%
# TODO: Add data quality checks
# - Missing values
# - Duplicates
# - Referential integrity
# - Outliers
