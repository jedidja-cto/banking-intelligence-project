# %% [markdown]
# # Fee Model Validation - Silver PAYU
#
# This notebook validates the fee calculation logic for the Silver Pay-as-you-use account.

# %%
import pandas as pd
import numpy as np
import yaml
import sys
sys.path.append('../code/src')

from fees.payu_fee_model import calculate_monthly_fee

# %% [markdown]
# ## Load Configuration

# %%
# Load Silver PAYU configuration
with open('../configs/account_types/silver_payu.yaml', 'r') as f:
    config = yaml.safe_load(f)

print("Account:", config['account_name'])
print("Monthly Fee:", config['monthly_fee'], "NAD")

# %% [markdown]
# ## Load Transaction Data

# %%
# Load transactions
transactions = pd.read_csv('../data/synthetic/transactions_sample.csv')
transactions['ts'] = pd.to_datetime(transactions['ts'])
print(f"Loaded {len(transactions)} transactions")

# %% [markdown]
# ## Test Fee Calculation

# %%
# TODO: Add fee calculation tests
# - Calculate fees for sample customers
# - Test with different transaction patterns
# - Validate against expected results
# - Document limitations

# %% [markdown]
# ## Sensitivity Analysis

# %%
# TODO: Add sensitivity analysis
# - How do fees change with transaction volume?
# - Impact of transaction type mix
# - Visualize fee components

# %% [markdown]
# ## Edge Cases

# %%
# TODO: Test edge cases
# - Zero transactions
# - Single transaction type
# - Extreme transaction volumes
# - Negative amounts (income)
